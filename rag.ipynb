# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag('What is the refund policy for the course?')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 assistant.rag('What is the refund policy for the course?')
#
# File c:\Users\baong\OneDrive\Documents\Projects\llm-zoomcamp-code\rag_helper.py:76, in RAGBase.rag(self, query)
#      75 def rag(self, query):
# ---> 76     search_results = self.search(query)
#      77     prompt = self.build_prompt(query, search_results)
#      78     answer = self.llm(prompt)
#
# File c:\Users\baong\OneDrive\Documents\Projects\llm-zoomcamp-code\rag_helper.py:38, in RAGBase.search(question, course)
#      35 boost_dict={"question": 2.0, "section": 0.5}
#      36 filter_dict = {"course": course}
# ---> 38 return index.search(
#      39     question,
#      40     boost_dict=boost_dict,
#      41     filter_dict=filter_dict,
#      42     num_results=5
#      43 )
#
# NameError: name 'index' is not defined
